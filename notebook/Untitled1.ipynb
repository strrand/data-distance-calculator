# %%
# pip install -U googlemaps

# %%
import streamlit as st
import googlemaps
import pandas as pd
from datetime import datetime
#import requests
#import io
import gdown
# Replace the file ID with your own
file_id = '11b0MJVrXV38Oy4gvmIcZpuRnQEAA52BQ'

url = f'https://drive.google.com/uc?id={file_id}'
excel_file_path = 'DAMAGE-GARAGE-LIST.csv'

gdown.download(url, excel_file_path, quiet=False)

df = pd.read_csv(excel_file_path)
df
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=11b0MJVrXV38Oy4gvmIcZpuRnQEAA52BQ
# To: /home/strrand/code/strrand/data-distance-calculator/notebook/DAMAGE-GARAGE-LIST.csv
# 100%|███████████████████████████████████████████████████████████████████████████████| 16.5k/16.5k [00:00<00:00, 437kB/s]
#       Område       Ort / Stad  Postkod                      Verkstad  \
# 0   Göteborg         Bäckebol  422 46               Din Bil Bäckebol
# 1   Göteborg          Eklanda   431 49               Din Bil Eklanda
# 2   Göteborg         Göteborg   412 63   Din Bil Göteborg (Grafiska)
# 3   Göteborg  Göteborg Tagene   425 37       Werksta Göteborg Tagene
# 4   Göteborg    Hisings Backa   422 23                  Din Bil Aröd
# ..       ...              ...      ...                           ...
# 86     Visby            Visby   621 99         Werksta Gotland Visby
# 87     Visby            Visby   621 41       Gotlands Plåt & Billack
# ...

# %%
import googlemaps
from datetime import datetime

# Replace YOUR_API_KEY with your actual API key
gmaps = googlemaps.Client(key='AIzaSyDfAsXwd2-eoRG121tgo766uqkuToEBpBc')

# Get user input for the origin and destination addresses
origin = input("Enter origin address: ")
destination = input("Enter destination address: ")

# Send a request to the API to get distance information
now = datetime.now()
directions_result = gmaps.directions(origin, destination, mode="driving", departure_time=now)

# Parse the response to extract the distance information
distance = directions_result[0]['legs'][0]['distance']['text']

# Print the distance between the two locations
print("The distance between", origin, "and", destination, "is", distance)
# Out:
# 2023-04-18 21:20:59.279 INFO    googlemaps.client: API queries_quota: 60
# Enter origin address: a
# Enter destination address: a
# ---------------------------------------------------------------------------
# ApiError                                  Traceback (most recent call last)
# Cell In [2], line 13
#      11 # Send a request to the API to get distance information
#      12 now = datetime.now()
# ---> 13 directions_result = gmaps.directions(origin, destination, mode="driving", departure_time=now)
#      15 # Parse the response to extract the distance information
#      16 distance = directions_result[0]['legs'][0]['distance']['text']
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/googlemaps/client.py:445, in make_api_method.<locals>.wrapper(*args, **kwargs)
#     442 @functools.wraps(func)
#     443 def wrapper(*args, **kwargs):
#     444     args[0]._extra_params = kwargs.pop("extra_params", None)
# --> 445     result = func(*args, **kwargs)
# ...

# %%
# path to excel -> /home/strrand/code/strrand/data-distance-calculator/data/DAMAGE_GARAGE_LIST.xlsx

# %%
# pip install openpyxl

# %%
import pandas as pd

# read Excel file
df2 = pd.read_excel('/home/strrand/code/strrand/data-distance-calculator/data/DAMAGE_GARAGE_LIST.xlsx')

# %%
df2.head()
# Out:
#      Område       Ort / Stad  Postkod                     Verkstad  \
# 0  Göteborg         Bäckebol  422 46              Din Bil Bäckebol
# 1  Göteborg          Eklanda   431 49              Din Bil Eklanda
# 2  Göteborg         Göteborg   412 63  Din Bil Göteborg (Grafiska)
# 3  Göteborg  Göteborg Tagene   425 37      Werksta Göteborg Tagene
# 4  Göteborg    Hisings Backa   422 23                 Din Bil Aröd
#
#                Adress     Telefonnr.                            Email   \
# 0  Transportgatan 57B  031-750 15 00  skodabackebolkm@skodagoteborg.se
# 1       Jolengatan 21  031-750 15 00         km.skoda@skodagoteborg.se
# 2    Grafiska vägen 4  031-750 15 00        bokning.grafiska@dinbil.se
# 3   Trankärrsgatan 14  0770-73 00 00             kundcenter@werksta.se
# 4    Exportgatan 23 a  031-750 15 00            Dbgb.kmbacka@dinbil.se
#
#     Maskinskador   Plåt & Lack  \
# 0             Ja           Nej
# 1             Ja           Nej
# 2             Ja            Ja
# ...

# %%
import pandas as pd

# read Excel file
df = pd.read_csv('/home/strrand/code/strrand/data-distance-calculator/data/DAMAGE-GARAGE-LIST.csv')

# %%
df.head()
# Out:
#      Område       Ort / Stad  Postkod                     Verkstad  \
# 0  Göteborg         Bäckebol  422 46              Din Bil Bäckebol
# 1  Göteborg          Eklanda   431 49              Din Bil Eklanda
# 2  Göteborg         Göteborg   412 63  Din Bil Göteborg (Grafiska)
# 3  Göteborg  Göteborg Tagene   425 37      Werksta Göteborg Tagene
# 4  Göteborg    Hisings Backa   422 23                 Din Bil Aröd
#
#                Adress     Telefonnr.                            Email   \
# 0  Transportgatan 57B  031-750 15 00  skodabackebolkm@skodagoteborg.se
# 1       Jolengatan 21  031-750 15 00         km.skoda@skodagoteborg.se
# 2    Grafiska vägen 4  031-750 15 00        bokning.grafiska@dinbil.se
# 3   Trankärrsgatan 14  0770-73 00 00             kundcenter@werksta.se
# 4    Exportgatan 23 a  031-750 15 00            Dbgb.kmbacka@dinbil.se
#
#     Maskinskador   Plåt & Lack  \
# 0             Ja           Nej
# 1             Ja           Nej
# 2             Ja            Ja
# ...

# %%
df.dtypes
# Out:
# Område                                               object
# Ort / Stad                                           object
# Postkod                                              object
# Verkstad                                             object
# Adress                                               object
# Telefonnr.                                           object
#   Email                                              object
#   Maskinskador                                       object
#   Plåt & Lack                                        object
# Reparerar alla märken utanför vagnskadegarantin?     object
# Auktoriserade märken (OBS!)                          object
# Unnamed: 11                                         float64
# Unnamed: 12                                         float64
# dtype: object

# %%
df['Postkod'] = df['Postkod'].str[:6]

# %%
df["Postkod"][0]
# Out:
# '422 46'

# %%
import googlemaps
from datetime import datetime

# Replace YOUR_API_KEY with your actual API key
gmaps = googlemaps.Client(key='AIzaSyDfAsXwd2-eoRG121tgo766uqkuToEBpBc')

# Get user input for the origin and destination addresses
origin = f"{df['Postkod'][0]} {df['Område'][0]}"
destination = input("Enter destination address: ")

# Send a request to the API to get distance information
now = datetime.now()
directions_result = gmaps.directions(origin, destination, mode="driving", departure_time=now)

# Parse the response to extract the distance information
distance = directions_result[0]['legs'][0]['distance']['text']

# Print the distance between the two locations
print("The distance between", origin, "and", destination, "is", distance)
# Out:
# Enter destination address: or,bergsvägen11 stockholm
# The distance between 422 46 Göteborg and or,bergsvägen11 stockholm is 470 km

# %% [markdown]
# # Data preparation Car model into list

# %%
df.head()
# Out:
#      Område       Ort / Stad Postkod                     Verkstad  \
# 0  Göteborg         Bäckebol  422 46             Din Bil Bäckebol
# 1  Göteborg          Eklanda  431 49              Din Bil Eklanda
# 2  Göteborg         Göteborg  412 63  Din Bil Göteborg (Grafiska)
# 3  Göteborg  Göteborg Tagene  425 37      Werksta Göteborg Tagene
# 4  Göteborg    Hisings Backa  422 23                 Din Bil Aröd
#
#                Adress     Telefonnr.                            Email   \
# 0  Transportgatan 57B  031-750 15 00  skodabackebolkm@skodagoteborg.se
# 1       Jolengatan 21  031-750 15 00         km.skoda@skodagoteborg.se
# 2    Grafiska vägen 4  031-750 15 00        bokning.grafiska@dinbil.se
# 3   Trankärrsgatan 14  0770-73 00 00             kundcenter@werksta.se
# 4    Exportgatan 23 a  031-750 15 00            Dbgb.kmbacka@dinbil.se
#
#     Maskinskador   Plåt & Lack  \
# 0             Ja           Nej
# 1             Ja           Nej
# 2             Ja            Ja
# ...

# %%
df.isnull().sum()
# Out:
# Område                                               1
# Ort / Stad                                           1
# Postkod                                              1
# Verkstad                                             1
# Adress                                               1
# Telefonnr.                                           1
#   Email                                              1
#   Maskinskador                                       1
#   Plåt & Lack                                        1
# Reparerar alla märken utanför vagnskadegarantin?     1
# Auktoriserade märken (OBS!)                          2
# Unnamed: 11                                         91
# Unnamed: 12                                         91
# dtype: int64

# %%
df['Auktoriserade märken (OBS!)'].fillna(value='unknown', inplace=True)

# %%
# Get the car model input from the user
car_model = input("Enter the car model: ")

# Filter the rows where the specified car model is present in the "Auktoriserade märken (OBS!)" column
filtered_df = df.loc[df["Auktoriserade märken (OBS!)"].str.contains(fr"\b{car_model}\b", case=False, regex=True)]

# Print the filtered DataFrame
print(filtered_df)
# Out:
# Enter the car model: Volvo
#            Område     Ort / Stad Postkod                          Verkstad  \
# 5        Göteborg  Hisings Kärra  425 37   Mechanum Skademottagning Tagene
# 9        Göteborg        Mölndal  431 53                  Mechanum Mölndal
# 11       Göteborg       Partille  433 38   Mechanum Skadeverkstad Partille
# 21       Norrland          Gävle  802 57                  Bilbolaget Gävle
# 24       Norrland      Sandviken  811 40              Bilbolaget Sandviken
# 33          Skåne          Malmö  211 24                    Mechanum Malmö
# 38          Skåne        Mölndal  431 53  Mechanum Skademottagning Mölndal
# 48        Småland          Nybro  382 45        Liljas Personbilar - Nybro
# 51        Småland       Tingsryd  362 30     Liljas Personbilar - Tingsryd
# 57        Småland          Växjö  352 46        Liljas Personbilar - Växjö
# 71  Stockholm Syd        Haninge  136 44         Werksta Stockholm Haninge
#
# ...

# %%
filtered_df.head()
# Out:
#       Område     Ort / Stad Postkod                         Verkstad  \
# 5   Göteborg  Hisings Kärra  425 37  Mechanum Skademottagning Tagene
# 9   Göteborg        Mölndal  431 53                 Mechanum Mölndal
# 11  Göteborg       Partille  433 38  Mechanum Skadeverkstad Partille
# 21  Norrland          Gävle  802 57                 Bilbolaget Gävle
# 24  Norrland      Sandviken  811 40             Bilbolaget Sandviken
#
#                     Adress     Telefonnr.                    Email   \
# 5        Trankärrsgatan 16  010-516 80 00         info@mechanum.com
# 9             ArgonGatan 6  010-516 80 00    leaseplan@mechanum.com
# 11        Benjamins väg 12  010-516 80 00         info@mechanum.com
# 21  Södra Kungsgatan 61-63    020-500 250  kundtjanst@bilbolaget.nu
# 24           Gävlevägen 88    020-500 250  kundtjanst@bilbolaget.nu
#
#      Maskinskador   Plåt & Lack  \
# 5              Ja            Ja
# 9              Ja           Nej
# 11             Ja            Ja
# ...

# %%
filtered_df.shape
# Out:
# (11, 13)

# %%
def filter_garage_list_by_car_model(excel_file_path):
    # read Excel file
    df = pd.read_csv(excel_file_path)

    # fill null values in the "Auktoriserade märken (OBS!)" column with "unknown"
    df['Auktoriserade märken (OBS!)'].fillna(value='unknown', inplace=True)

    # Get the car model input from the user
    car_model = input("Enter the car model: ")

    # Filter the rows where the specified car model is present in the "Auktoriserade märken (OBS!)" column
    filtered_df = df.loc[df["Auktoriserade märken (OBS!)"].str.contains(fr"\b{car_model}\b", case=False, regex=True)]

    return filtered_df

filtered_df = filter_garage_list_by_car_model('/home/strrand/code/strrand/data-distance-calculator/data/DAMAGE-GARAGE-LIST.csv')
filtered_df.shape
# Out:
# Enter the car model: Opel
# (11, 13)

# %% [markdown]
# # Loop over google maps with the filtered_df with outcome of the top 3 closest garages

# %%
filtered_df.head()
# Out:
#       Område     Ort / Stad Postkod                         Verkstad  \
# 5   Göteborg  Hisings Kärra  425 37  Mechanum Skademottagning Tagene
# 9   Göteborg        Mölndal  431 53                 Mechanum Mölndal
# 11  Göteborg       Partille  433 38  Mechanum Skadeverkstad Partille
# 21  Norrland          Gävle  802 57                 Bilbolaget Gävle
# 24  Norrland      Sandviken  811 40             Bilbolaget Sandviken
#
#                     Adress     Telefonnr.                    Email   \
# 5        Trankärrsgatan 16  010-516 80 00         info@mechanum.com
# 9             ArgonGatan 6  010-516 80 00    leaseplan@mechanum.com
# 11        Benjamins väg 12  010-516 80 00         info@mechanum.com
# 21  Södra Kungsgatan 61-63    020-500 250  kundtjanst@bilbolaget.nu
# 24           Gävlevägen 88    020-500 250  kundtjanst@bilbolaget.nu
#
#      Maskinskador   Plåt & Lack  \
# 5              Ja            Ja
# 9              Ja           Nej
# 11             Ja            Ja
# ...

# %%
for index, row in filtered_df.iterrows():
    # Get the origin and destination addresses
    print(f"{row['Adress']}, {row['Ort / Stad']}")
    #print(f"{row['Verkstad']}")
# Out:
# Trankärrsgatan 16, Hisings Kärra
# ArgonGatan 6, Mölndal
# Benjamins väg 12, Partille
# Södra Kungsgatan 61-63, Gävle
# Gävlevägen 88, Sandviken
# Västkustvägen 17, Malmö
# Argongatan 32, Mölndal
# Jutarnas Väg 5, Nybro
# Södra Storgatan 113, Tingsryd
# Ljungadalsgatan 1, Växjö
# Anläggarvägen 18, Haninge

# %%
def get_shortest_distances(filtered_df):
    # Replace YOUR_API_KEY with your actual API key
    gmaps = googlemaps.Client(key='AIzaSyDfAsXwd2-eoRG121tgo766uqkuToEBpBc')

    # Define an empty list to store the distances
    distances = []
    
    # User input the current location/address
    destination = input("Enter your address: ")
        
    # Loop over the filtered addresses and get the distances
    for index, row in filtered_df.iterrows():
        # Get the origin and destination addresses
        origin = f"{row['Adress']}, {row['Ort / Stad']}"
        garage = f"{row['Verkstad']}"
        
        # Send a request to the API to get distance information
        now = datetime.now()
        directions_result = gmaps.directions(origin, destination, mode="driving", departure_time=now)

        # Parse the response to extract the distance information
        distance = directions_result[0]['legs'][0]['distance']['text']

        # Add the distance to the list
        distances.append((origin, garage, distance))

    # Sort the distances in ascending order
    distances.sort(key=lambda x: x[2])

    # Display the top 3 shortest distances to the user
    print("The top 3 shortest distances are:")
    for i, (origin, garage, distance) in enumerate(distances):
        print(f"{garage}, {distance}")
        
get_shortest_distances(filtered_df)
# Out:
# 2023-04-19 17:29:16.225 INFO    googlemaps.client: API queries_quota: 60
# Enter your address: Ormbergsvägen 11 stockholm
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/urllib3/connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/urllib3/util/connection.py:72, in create_connection(address, timeout, source_address, socket_options)
#      68     return six.raise_from(
#      69         LocationParseError(u"'%s', label empty or too long" % host), None
#      70     )
# ---> 72 for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
# ...

# %%
def get_shortest_distances(filtered_df):
    # Replace YOUR_API_KEY with your actual API key
    gmaps = googlemaps.Client(key='AIzaSyCCPq1id51cps5dmPGlmM3bFkoeJ6bWPB8')

    # Define an empty list to store the distances
    distances = []

    # User input the current location/address
    destination = input("Enter your address: ")

    # Loop over the filtered addresses and get the distances
    for index, row in filtered_df.iterrows():
        # Get the origin and destination addresses
        origin = f"{row['Adress']}, {row['Ort / Stad']}"
        garage = f"{row['Verkstad']}"

        # Send a request to the API to get distance information
        now = datetime.now()
        directions_result = gmaps.directions(origin, destination, mode="driving", departure_time=now)

        # Parse the response to extract the distance information
        distance = directions_result[0]['legs'][0]['distance']['value'] / 1000  # Convert to km

        # Add the distance to the list
        distances.append((origin, garage, distance))

    # Sort the distances in ascending order based on the numeric value of the distance
    distances.sort(key=lambda x: x[2])

    # Print the sorted distances
    for origin, garage, distance in distances:
        print(f"{garage}: {distance:.1f} km")
        
get_shortest_distances(filtered_df)
# Out:
# 2023-04-19 17:30:29.522 INFO    googlemaps.client: API queries_quota: 60
# Enter your address: Ormbergvägen 11 stockholm
# Werksta Stockholm Haninge: 23.3 km
# Bilbolaget Gävle: 171.6 km
# Bilbolaget Sandviken: 192.2 km
# Liljas Personbilar - Växjö: 415.1 km
# Liljas Personbilar - Nybro: 420.3 km
# Liljas Personbilar - Tingsryd: 456.0 km
# Mechanum Skadeverkstad Partille: 457.7 km
# Mechanum Mölndal: 465.8 km
# Mechanum Skademottagning Mölndal: 466.0 km
# Mechanum Skademottagning Tagene: 471.9 km
# Mechanum Malmö: 604.5 km

# %% [markdown]
# # include all code in one function

# %%
def filter_garage_list_by_car_model(excel_file_path):
    # read Excel file
    df = pd.read_csv(excel_file_path)

    # fill null values in the "Auktoriserade märken (OBS!)" column with "unknown"
    df['Auktoriserade märken (OBS!)'].fillna(value='unknown', inplace=True)

    # Get the car model input from the user
    car_model = input("Enter the car model: ")
    
    # Convert car_model to lowercase
    car_model = car_model.lower()

    # Filter the rows where the specified car model is present in the "Auktoriserade märken (OBS!)" column
    filtered_df = df.loc[df["Auktoriserade märken (OBS!)"].str.lower().str.contains(fr"\b{car_model}\b", case=False, regex=True)]

    return filtered_df

def get_shortest_distances(filtered_df):
    # Replace YOUR_API_KEY with your actual API key
    gmaps = googlemaps.Client(key='AIzaSyCCPq1id51cps5dmPGlmM3bFkoeJ6bWPB8')

    # Define an empty list to store the distances
    distances = []
    
    # User input the current location/address
    destination = input("Enter your address: ")
        
    # Loop over the filtered addresses and get the distances
    for index, row in filtered_df.iterrows():
        # Get the origin and destination addresses
        origin = f"{row['Adress']}, {row['Ort / Stad']}"
        garage = f"{row['Verkstad']}"
        
        # Send a request to the API to get distance information
        now = datetime.now()
        directions_result = gmaps.directions(origin, destination, mode="driving", departure_time=now)

        # Parse the response to extract the distance information
        distance = directions_result[0]['legs'][0]['distance']['text']

        # Add the distance to the list
        distances.append((origin, garage, distance))

    # Sort the distances in ascending order
    distances.sort(key=lambda x: x[2])

    # Display the top 3 shortest distances to the user
    print("The top 3 shortest garage distances are:")
    for i, (origin, garage, distance) in enumerate(distances[:3]):
        print(f"{i+1}. The distance between {garage}, {origin} and {destination} is {distance}")
        

filtered_df = filter_garage_list_by_car_model('/home/strrand/code/strrand/data-distance-calculator/data/DAMAGE-GARAGE-LIST.csv')
get_shortest_distances(filtered_df)
# Out:
# Enter the car model: Opel
# Enter your address: Ormbergvägen 11 stockholm
# The top 3 shortest garage distances are:
# 1. The distance between Werksta Norrköping Butängen, Fredriksdalsgatan 19, Norrköping and Ormbergvägen 11 stockholm is 155 km
# 2. The distance between Holmgrens Bil AB Huskvarna - Vätternäs, Thulevägen 2, Huskvarna and Ormbergvägen 11 stockholm is 313 km
# 3. The distance between Bilkompani Sydost AB, Inkörningsvägen 1, Oskarshamn and Ormbergvägen 11 stockholm is 337 km
